# %% [markdown]
# ## IDBM 영화 순위 분석

# %% [markdown]
# ## IMDB Top 250 Movies
# ### About Dataset
# This dataset is having the data of the top 250 Movies as per their IMDB rating listed on the official website of IMDB
#
# ### Features
#
# rank - Movie Rank as per IMDB rating <br>
# movie_id - Movie ID <br>
# title - Name of the Movie <br>
# year - Year of Movie release <br>
# link - URL for the Movie <br>
# imdb_votes - Number of people who voted for the IMDB rating <br>
# imdb_rating - Rating of the Movie <br>
# certificate - Movie Certification <br>
# duration - Duration of the Movie <br>
# genre - Genre of the Movie <br>
# cast_id - ID of the cast member who have worked on the Movie <br>
# cast_name - Name of the cast member who have worked on the Movie <br>
# director_id - ID of the director who have directed the Movie <br>
# director_name - Name of the director who have directed the Movie <br>
# writer_id - ID of the writer who have wrote script for the Movie <br>
# writer_name - Name of the writer who have wrote script for the Movie <br>
# storyline - Storyline of the Movie <br>
# user_id - ID of the user who wrote review for the Movie <br>
# user_name - Name of the user who wrote review for the Movie <br>
# review_id - ID of the user review <br>
# review_title - Short review <br>
# review_content - Long review <br>

# %% [markdown]
# ### 분석
# - 어떤 장르의 영화가 많은 지
# - 투표 수에 따른 순위
# - 어느 년도에 출시된 영화가 많은 지
# - 어느 감독의 영화가 많은 지

# %%
import pandas as pd

df = pd.read_csv('../data/movies.csv')

# %%
df.head()
# Out:
#    rank   movie_id                     title  year  \
# 0     1  tt0111161  The Shawshank Redemption  1994
# 1     2  tt0068646             The Godfather  1972
# 2     3  tt0468569           The Dark Knight  2008
# 3     4  tt0071562     The Godfather Part II  1974
# 4     5  tt0050083              12 Angry Men  1957
#
#                                    link imbd_votes  imbd_rating certificate  \
# 0  https://www.imdb.com/title/tt0111161  2,711,075          9.3           R
# 1  https://www.imdb.com/title/tt0068646  1,882,829          9.2           R
# 2  https://www.imdb.com/title/tt0468569  2,684,051          9.0       PG-13
# 3  https://www.imdb.com/title/tt0071562  1,285,350          9.0           R
# 4  https://www.imdb.com/title/tt0050083    800,954          9.0    Approved
#
#   duration               genre  ... director_id         director_name  \
# 0   2h 22m               Drama  ...   nm0001104        Frank Darabont
# 1   2h 55m         Crime,Drama  ...   nm0000338  Francis Ford Coppola
# 2   2h 32m  Action,Crime,Drama  ...   nm0634240     Christopher Nolan
# 3   3h 22m         Crime,Drama  ...   nm0000338  Francis Ford Coppola
# 4   1h 36m         Crime,Drama  ...   nm0001486          Sidney Lumet
#
#                                            writer_id  \
# 0                                nm0000175,nm0001104
# 1                                nm0701374,nm0000338
# 2  tt0468569,nm0634300,nm0634240,nm0275286,tt0468569
# 3                                nm0000338,nm0701374
# 4                                          nm0741627
#
#                                          writer_name  \
# 0                        Stephen King,Frank Darabont
# 1                    Mario Puzo,Francis Ford Coppola
# 2  Writers,Jonathan Nolan,Christopher Nolan,David...
# 3                    Francis Ford Coppola,Mario Puzo
# 4                                      Reginald Rose
#
#                                            storyline  \
# 0  Over the course of several years, two convicts...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
#
#                                              user_id  \
# 0  ur16161013,ur15311310,ur0265899,ur16117882,ur1...
# 1  ur24740649,ur86182727,ur15794099,ur15311310,ur...
# 2  ur87850731,ur1293485,ur129557514,ur12449122,ur...
# 3  ur0176092,ur0688559,ur92260614,ur0200644,ur117...
# 4  ur1318549,ur0643062,ur0688559,ur20552756,ur945...
#
#                                            user_name  \
# 0  hitchcockthelegend,Sleepin_Dragon,EyeDunno,ale...
# 1  CalRhys,andrewburgereviews,gogoschka-1,Sleepin...
# 2  MrHeraclius,Smells_Like_Cheese,dseferaj,little...
# 3  Nazi_Fighter_David,tfrizzell,umunir-36959,DanB...
# 4  uds3,tedg,tfrizzell,TheLittleSongbird,henrique...
#
#                                            review_id  \
# 0  rw2284594,rw6606154,rw1221355,rw1822343,rw1288...
# 1  rw3038370,rw4756923,rw4059579,rw6568526,rw1897...
# 2  rw5478826,rw1914442,rw6606026,rw1917099,rw5170...
# 3  rw0135607,rw0135487,rw5049900,rw0135526,rw0135...
# 4  rw0060044,rw0060025,rw0060034,rw2262425,rw5448...
#
#                                         review_title  \
# 0  Some birds aren't meant to be caged.,An incred...
# 1  The Pinnacle Of Flawless Films!,An offer so go...
# 2  The Dark Knight,The Batman of our dreams! So m...
# 3  Breathtaking in its scope and tragic grandeur....
# 4  The over-used term "classic movie" really come...
#
#                                       review_content
# 0  The Shawshank Redemption is written and direct...
# 1  'The Godfather' is the pinnacle of flawless fi...
# 2  Confidently directed, dark, brooding, and pack...
# 3  Coppola's masterpiece is rivaled only by "The ...
# 4  This once-in-a-generation masterpiece simply h...
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['rank', 'movie_id', 'title', 'year', 'link', 'imbd_votes',
#        'imbd_rating', 'certificate', 'duration', 'genre', 'cast_id',
#        'cast_name', 'director_id', 'director_name', 'writer_id', 'writer_name',
#        'storyline', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content'],
#       dtype='object')

# %%
# 필요한 컬럼만 슬라이싱
data = df[['rank', 'movie_id', 'title', 'year', 'link', 'imbd_votes', 'imbd_rating', 'duration', 'genre', 'cast_id', 'cast_name', 'director_id', 'director_name', 'writer_id', 'writer_name',
       'storyline']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           250 non-null    int64
#  1   movie_id       250 non-null    object
#  2   title          250 non-null    object
#  3   year           250 non-null    int64
#  4   link           250 non-null    object
#  5   imbd_votes     250 non-null    object
#  6   imbd_rating    250 non-null    float64
#  7   duration       250 non-null    object
#  8   genre          250 non-null    object
#  9   cast_id        250 non-null    object
#  10  cast_name      250 non-null    object
#  11  director_id    250 non-null    object
#  12  director_name  250 non-null    object
#  13  writer_id      250 non-null    object
#  14  writer_name    250 non-null    object
#  15  storyline      250 non-null    object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 31.4+ KB

# %%
# 결측치 확인
data.isnull().sum()
# Out:
# rank             0
# movie_id         0
# title            0
# year             0
# link             0
# imbd_votes       0
# imbd_rating      0
# duration         0
# genre            0
# cast_id          0
# cast_name        0
# director_id      0
# director_name    0
# writer_id        0
# writer_name      0
# storyline        0
# dtype: int64

# %% [markdown]
# * imbd_votes: 정수형 변환

# %%
data['imbd_votes'][0] # ',' 를 없애야 int로 변환가능
# Out:
# '2,711,075'

# %%
# 천 단위 콤마(,) 삭제 후 정수형 변환
data['imbd_votes'] = data['imbd_votes'].str.replace(',', '').astype('int64')
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_10896\2550449298.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['imbd_votes'] = data['imbd_votes'].str.replace(',', '').astype('int64')

# %%
data['imbd_votes'].head()
# Out:
# 0    2711075
# 1    1882829
# 2    2684051
# 3    1285350
# 4     800954
# Name: imbd_votes, dtype: int64

# %%
data.head()
# Out:
#    rank   movie_id                     title  year  \
# 0     1  tt0111161  The Shawshank Redemption  1994
# 1     2  tt0068646             The Godfather  1972
# 2     3  tt0468569           The Dark Knight  2008
# 3     4  tt0071562     The Godfather Part II  1974
# 4     5  tt0050083              12 Angry Men  1957
#
#                                    link  imbd_votes  imbd_rating duration  \
# 0  https://www.imdb.com/title/tt0111161     2711075          9.3   2h 22m
# 1  https://www.imdb.com/title/tt0068646     1882829          9.2   2h 55m
# 2  https://www.imdb.com/title/tt0468569     2684051          9.0   2h 32m
# 3  https://www.imdb.com/title/tt0071562     1285350          9.0   3h 22m
# 4  https://www.imdb.com/title/tt0050083      800954          9.0   1h 36m
#
#                 genre                                            cast_id  \
# 0               Drama  nm0000209,nm0000151,nm0348409,nm0006669,nm0000...
# 1         Crime,Drama  nm0000008,nm0000199,nm0001001,nm0144710,nm0000...
# 2  Action,Crime,Drama  nm0000288,nm0005132,nm0001173,nm0000323,nm0350...
# 3         Crime,Drama  nm0000199,nm0000380,nm0000473,nm0000134,nm0001...
# 4         Crime,Drama  nm0000842,nm0275835,nm0002011,nm0550855,nm0001...
#
#                                            cast_name director_id  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...   nm0001104
# 1  Marlon Brando,Al Pacino,James Caan,Richard S. ...   nm0000338
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...   nm0634240
# 3  Al Pacino,Robert Duvall,Diane Keaton,Robert De...   nm0000338
# 4  Martin Balsam,John Fiedler,Lee J. Cobb,E.G. Ma...   nm0001486
#
#           director_name                                          writer_id  \
# 0        Frank Darabont                                nm0000175,nm0001104
# 1  Francis Ford Coppola                                nm0701374,nm0000338
# 2     Christopher Nolan  tt0468569,nm0634300,nm0634240,nm0275286,tt0468569
# 3  Francis Ford Coppola                                nm0000338,nm0701374
# 4          Sidney Lumet                                          nm0741627
#
#                                          writer_name  \
# 0                        Stephen King,Frank Darabont
# 1                    Mario Puzo,Francis Ford Coppola
# 2  Writers,Jonathan Nolan,Christopher Nolan,David...
# 3                    Francis Ford Coppola,Mario Puzo
# 4                                      Reginald Rose
#
#                                            storyline
# 0  Over the course of several years, two convicts...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...

# %%
data.to_csv('../data/movie_added.csv', index = False)

# %%
data.columns
# Out:
# Index(['rank', 'movie_id', 'title', 'year', 'link', 'imbd_votes',
#        'imbd_rating', 'duration', 'genre', 'cast_id', 'cast_name',
#        'director_id', 'director_name', 'writer_id', 'writer_name',
#        'storyline'],
#       dtype='object')

# %%
added = pd.read_csv('../data/movie_added.csv')
# Out:
#      rank   movie_id               title  year  \
# 18     19  tt0114369               Se7en  1995
# 39     40  tt0114814  The Usual Suspects  1995
# 73     74  tt0114709           Toy Story  1995
# 75     76  tt0112573          Braveheart  1995
# 108   109  tt0113277                Heat  1995
# 135   136  tt0112641              Casino  1995
# 178   179  tt0112471      Before Sunrise  1995
# 228   229  tt0113247            La haine  1995
#
#                                      link  imbd_votes  imbd_rating duration  \
# 18   https://www.imdb.com/title/tt0114369     1674020          8.6    2h 7m
# 39   https://www.imdb.com/title/tt0114814     1095033          8.5   1h 46m
# 73   https://www.imdb.com/title/tt0114709     1005591          8.3   1h 21m
# 75   https://www.imdb.com/title/tt0112573     1046807          8.4   2h 58m
# 108  https://www.imdb.com/title/tt0113277      664714          8.3   2h 50m
# 135  https://www.imdb.com/title/tt0112641      528069          8.2   2h 58m
# 178  https://www.imdb.com/title/tt0112471      315432          8.1   1h 41m
# 228  https://www.imdb.com/title/tt0113247      178165          8.1   1h 38m
#
#                           genre  \
# 18          Crime,Drama,Mystery
# 39          Crime,Drama,Mystery
# 73   Animation,Adventure,Comedy
# 75      Biography,Drama,History
# 108          Action,Crime,Drama
# 135                 Crime,Drama
# 178               Drama,Romance
# 228                 Crime,Drama
#
#                                                cast_id  \
# 18   nm0000151,nm0001825,nm0669254,nm0000093,nm0000...
# 39   nm0000286,nm0000321,nm0001125,nm0001629,nm0000...
# 73   nm0000158,nm0000741,nm0725543,nm0001815,nm0001...
# 75   nm0732703,nm0492566,nm0625729,nm0181920,nm0569...
# 108  nm0000199,nm0000134,nm0000174,nm0000685,nm0001...
# 135  nm0000134,nm0000232,nm0000582,nm0000249,nm0725...
# 178  nm0000160,nm0000365,nm0248600,nm0702541,nm0115...
# 228  nm0001993,nm0468003,nm0846548,nm0315760,nm0813...
#
#                                              cast_name director_id  \
# 18   Morgan Freeman,Andrew Kevin Walker,Daniel Zaca...   nm0000399
# 39   Stephen Baldwin,Gabriel Byrne,Benicio Del Toro...   nm0001741
# 73   Tom Hanks,Tim Allen,Don Rickles,Jim Varney,Wal...   nm0005124
# 75   James Robinson,Sean Lawlor,Sandy Nelson,James ...   nm0000154
# 108  Al Pacino,Robert De Niro,Val Kilmer,Jon Voight...   nm0000520
# 135  Robert De Niro,Sharon Stone,Joe Pesci,James Wo...   nm0000217
# 178  Ethan Hawke,Julie Delpy,Andrea Eckert,Hanno Pö...   nm0000500
# 228  Vincent Cassel,Hubert Koundé,Saïd Taghmaoui,Ab...   nm0440913
#
#          director_name                                          writer_id  \
# 18       David Fincher                                          nm0001825
# 39        Bryan Singer                                          nm0003160
# 73       John Lasseter  tt0114709,nm0005124,nm0230032,nm0004056,tt0114709
# 75          Mel Gibson                                          nm0908824
# 108       Michael Mann                                          nm0000520
# 135    Martin Scorsese                                nm0683380,nm0000217
# 178  Richard Linklater                                nm0000500,nm0471811
# 228  Mathieu Kassovitz                                          nm0440913
#
#                                            writer_name  \
# 18                                 Andrew Kevin Walker
# 39                               Christopher McQuarrie
# 73   Writers,John Lasseter,Pete Docter,Andrew Stanton,
# 75                                     Randall Wallace
# 108                                       Michael Mann
# 135                   Nicholas Pileggi,Martin Scorsese
# 178                       Richard Linklater,Kim Krizan
# 228                                  Mathieu Kassovitz
#
#                                              storyline
# 18   Two detectives, a rookie and a veteran, hunt a...
# 39   A sole survivor tells of the twisty events lea...
# 73   A cowboy doll is profoundly threatened and jea...
# 75   Scottish warrior William Wallace leads his cou...
# 108  A group of high-end professional thieves start...
# 135  A tale of greed, deception, money, power, and ...
# 178  A young man and woman meet on a train in Europ...
# 228  24 hours in the lives of three young men in th...

# %% [markdown]
# ### NOTE

# %%
year_count = added['year'].value_counts()[:10]

# %%
year_count = year_count.reset_index()
year_count_df = pd.DataFrame(year_count)
year_count_df = year_count_df.rename(columns={'year':'count', 'index':'year'})
year_count_df['year'].to_list()
# Out:
# [1995, 2004, 2009, 1957, 2003, 2019, 1999, 1975, 2007, 2011]

# %%
new_list = []
for i, year in enumerate(year_count.index):
    new_list.append(str(i)+'위('+str(year)+')')
new_list
# Out:
# ['0위(1995)',
#  '1위(2004)',
#  '2위(2009)',
#  '3위(1957)',
#  '4위(2003)',
#  '5위(2019)',
#  '6위(1999)',
#  '7위(1975)',
#  '8위(2007)',
#  '9위(2011)']

# %%
year_count.index = new_list
year_count
# Out:
# 0위(1995)    8
# 1위(2004)    7
# 2위(2009)    6
# 3위(1957)    6
# 4위(2003)    6
# 5위(2019)    6
# 6위(1999)    6
# 7위(1975)    5
# 8위(2007)    5
# 9위(2011)    5
# Name: year, dtype: int64

# %%
# year_count_sorted = year_count.sort_values(ascending=False)
# st.bar_chart(year_count_sorted, x = 'year')

# %% [markdown]
# - 인덱스 입력해서 데이터 추출하기

# %%
added.loc[6]['link']
# Out:
# 'https://www.imdb.com/title/tt0167260'
