# %% [markdown]
# Business Understanding -> Data Understanding -> Data Preparation -> Modeling -> Evaluation -> Deployment

# %% [markdown]
# - Business Understanding: Netflix 영화 추천 시스템_협업 필터링

# %% [markdown]
# - Data Understanding

# %% [markdown]
# > Movie.csv

# %%
import pandas as pd
movie_df = pd.read_csv('data/Netflix_Dataset_Movie.csv')
movie_df.head()
# Out:
#    Movie_ID  Year                          Name
# 0         1  2003               Dinosaur Planet
# 1         2  2004    Isle of Man TT 2004 Review
# 2         3  1997                     Character
# 3         4  1994  Paula Abdul's Get Up & Dance
# 4         5  2004      The Rise and Fall of ECW

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Movie_ID  17770 non-null  int64
#  1   Year      17770 non-null  int64
#  2   Name      17770 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 416.6+ KB

# %% [markdown]
# > Rating.csv

# %%
rating_df = pd.read_csv('data/Netflix_Dataset_Rating.csv')
rating_df.head()
# Out:
#    User_ID  Rating  Movie_ID
# 0   712664       5         3
# 1  1331154       4         3
# 2  2632461       3         3
# 3    44937       5         3
# 4   656399       4         3

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17337458 entries, 0 to 17337457
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   User_ID   int64
#  1   Rating    int64
#  2   Movie_ID  int64
# dtypes: int64(3)
# memory usage: 396.8 MB

# %%
rating_df['Rating'].value_counts()
# Out:
# 4    5901368
# 3    5185650
# 5    3769803
# 2    1759281
# 1     721356
# Name: Rating, dtype: int64

# %% [markdown]
# > EDA

# %%
# user_groupby = rating_df.groupby('User_ID')
# movie_groupby = rating_df.groupby('Movie_ID')

# average_user_rating = user_groupby['Rating'].mean()
# number_of_ratings_by_user = user_groupby['Rating'].count()
# average_movie_rating = movie_groupby['Rating'].mean()
# number_of_movie_ratings = movie_groupby['Rating'].count()

# average_user_rating.name = 'avg_rating'
# number_of_ratings_by_user.name  = 'n_ratings'
# average_movie_rating.name  = 'avg_rating'
# number_of_movie_ratings.name  = 'n_ratings'

# average_user_rating.sort_values(ascending=False)

# %%
movie_rating_df = movie_df.merge(rating_df, how='left', on='Movie_ID')
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17353878 entries, 0 to 17353877
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Movie_ID  int64
#  1   Year      int64
#  2   Name      object
#  3   User_ID   float64
#  4   Rating    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 794.4+ MB

# %%
movie_rating_df.isnull().sum()
# Out:
# Movie_ID        0
# Year            0
# Name            0
# User_ID     16420
# Rating      16420
# dtype: int64

# %%
movie_rating_df = movie_rating_df.drop(columns=['Year', 'Name'])
movie_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17353878 entries, 0 to 17353877
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Movie_ID  int64
#  1   User_ID   float64
#  2   Rating    float64
# dtypes: float64(2), int64(1)
# memory usage: 529.6 MB

# %%
movie_rating_df.isnull().sum()
# Out:
# Movie_ID        0
# User_ID     16420
# Rating      16420
# dtype: int64

# %%
moviemat = movie_rating_df.pivot_table(index='User_ID', columns='Movie_ID', values='Rating')
moviemat.head()
# Out:
# Movie_ID  3     8     16    17    18    26    28    30    32    33    ...  \
# User_ID                                                               ...
# 6.0        NaN   NaN   NaN   NaN   NaN   NaN   NaN   3.0   NaN   NaN  ...
# 7.0        NaN   5.0   NaN   NaN   NaN   NaN   4.0   5.0   NaN   NaN  ...
# 79.0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   3.0   NaN   NaN  ...
# 97.0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 134.0      NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN   NaN  ...
#
# Movie_ID  4472  4474  4478  4479  4485  4488  4490  4492  4493  4496
# User_ID
# 6.0        3.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7.0        3.0   NaN   NaN   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 79.0       4.0   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN
# 97.0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 134.0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 1350 columns]

# %%
moviemat.shape
# Out:
# (143458, 1350)

# %%
movie_pivot = movie_rating_df.pivot_table(index='Movie_ID', columns='User_ID', values='Rating')
movie_pivot.shape
# Out:
# (1350, 143458)

# %%
movie_pivot.head()
# Out:
# User_ID   6.0        7.0        79.0       97.0       134.0      169.0      \
# Movie_ID
# 3               NaN        NaN        NaN        NaN        NaN        NaN
# 8               NaN        5.0        NaN        NaN        NaN        NaN
# 16              NaN        NaN        NaN        NaN        NaN        NaN
# 17              NaN        NaN        NaN        NaN        NaN        NaN
# 18              NaN        NaN        NaN        NaN        NaN        NaN
#
# User_ID   183.0      188.0      195.0      199.0      ...  2649308.0  \
# Movie_ID                                              ...
# 3               NaN        NaN        NaN        NaN  ...        NaN
# 8               NaN        NaN        NaN        NaN  ...        NaN
# 16              NaN        NaN        NaN        NaN  ...        NaN
# 17              NaN        NaN        NaN        NaN  ...        NaN
# 18              NaN        NaN        NaN        NaN  ...        4.0
#
# User_ID   2649328.0  2649331.0  2649335.0  2649336.0  2649370.0  2649378.0  \
# Movie_ID
# 3               NaN        NaN        NaN        NaN        NaN        NaN
# 8               NaN        NaN        NaN        4.0        NaN        NaN
# 16              NaN        NaN        NaN        NaN        NaN        NaN
# 17              NaN        NaN        NaN        NaN        NaN        NaN
# 18              NaN        NaN        NaN        NaN        NaN        NaN
#
# User_ID   2649388.0  2649426.0  2649429.0
# Movie_ID
# 3               NaN        NaN        NaN
# 8               NaN        NaN        NaN
# 16              NaN        NaN        NaN
# 17              NaN        4.0        NaN
# 18              NaN        NaN        NaN
#
# [5 rows x 143458 columns]

# %%
movie_pivot.fillna(0, inplace=True)
movie_pivot = movie_pivot.astype('int8')
movie_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350 entries, 3 to 4496
# Columns: 143458 entries, 6.0 to 2649429.0
# dtypes: int8(143458)
# memory usage: 184.7 MB

# %%
movie_pivot.head()
# Out:
# User_ID   6.0        7.0        79.0       97.0       134.0      169.0      \
# Movie_ID
# 3                 0          0          0          0          0          0
# 8                 0          5          0          0          0          0
# 16                0          0          0          0          0          0
# 17                0          0          0          0          0          0
# 18                0          0          0          0          0          0
#
# User_ID   183.0      188.0      195.0      199.0      ...  2649308.0  \
# Movie_ID                                              ...
# 3                 0          0          0          0  ...          0
# 8                 0          0          0          0  ...          0
# 16                0          0          0          0  ...          0
# 17                0          0          0          0  ...          0
# 18                0          0          0          0  ...          4
#
# User_ID   2649328.0  2649331.0  2649335.0  2649336.0  2649370.0  2649378.0  \
# Movie_ID
# 3                 0          0          0          0          0          0
# 8                 0          0          0          4          0          0
# 16                0          0          0          0          0          0
# 17                0          0          0          0          0          0
# 18                0          0          0          0          0          0
#
# User_ID   2649388.0  2649426.0  2649429.0
# Movie_ID
# 3                 0          0          0
# 8                 0          0          0
# 16                0          0          0
# 17                0          4          0
# 18                0          0          0
#
# [5 rows x 143458 columns]

# %%
movie_pivot.shape
# Out:
# (1350, 143458)

# %% [markdown]
# - Recommendation System

# %%
from sklearn.neighbors import NearestNeighbors

# %%
n_neighbors = 11
KNN = NearestNeighbors(metric='cosine', n_neighbors=n_neighbors, n_jobs=-1)

# %%
KNN.fit(movie_pivot)
# Out:
# NearestNeighbors(metric='cosine', n_jobs=-1, n_neighbors=11)

# %%
distances, indices = KNN.kneighbors(movie_pivot)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 distances, indices = KNN.kneighbors(movie_pivot)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:861, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     858     else:
#     859         kwds = self.effective_metric_params_
# --> 861     chunked_results = list(
#     862         pairwise_distances_chunked(
#     863             X,
#     864             self._fit_X,
#     865             reduce_func=reduce_func,
#     866             metric=self.effective_metric_,
#     867             n_jobs=n_jobs,
#     868             **kwds,
#     869         )
#     870     )
#     872 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     873     if issparse(X):
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1584, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1582 fd = delayed(_dist_wrapper)
#    1583 ret = np.empty((X.shape[0], Y.shape[0]), dtype=dtype, order="F")
# -> 1584 Parallel(backend="threading", n_jobs=n_jobs)(
#    1585     fd(func, ret, s, X, Y[s], **kwds)
#    1586     for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs))
#    1587 )
#    1589 if (X is Y or Y is None) and func is euclidean_distances:
#    1590     # zeroing diagonal for euclidean norm.
#    1591     # TODO: do it also for other norms.
#    1592     np.fill_diagonal(ret, 0)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\joblib\parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File c:\Users\k9942\anaconda3\lib\site-packages\joblib\parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File c:\Users\k9942\anaconda3\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File c:\Users\k9942\anaconda3\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File c:\Users\k9942\anaconda3\lib\site-packages\joblib\_parallel_backends.py:595, in SafeFunction.__call__(self, *args, **kwargs)
#     593 def __call__(self, *args, **kwargs):
#     594     try:
# --> 595         return self.func(*args, **kwargs)
#     596     except KeyboardInterrupt as e:
#     597         # We capture the KeyboardInterrupt and reraise it as
#     598         # something different, as multiprocessing does not
#     599         # interrupt processing for a KeyboardInterrupt
#     600         raise WorkerInterrupt() from e
#
# File c:\Users\k9942\anaconda3\lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File c:\Users\k9942\anaconda3\lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1567, in _dist_wrapper(dist_func, dist_matrix, slice_, *args, **kwargs)
#    1565 def _dist_wrapper(dist_func, dist_matrix, slice_, *args, **kwargs):
#    1566     """Write in-place to a slice of a distance matrix."""
# -> 1567     dist_matrix[:, slice_] = dist_func(*args, **kwargs)
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1000, in cosine_distances(X, Y)
#     974 """Compute cosine distance between samples in X and Y.
#     975
#     976 Cosine distance is defined as 1.0 minus the cosine similarity.
#    (...)
#     997 scipy.spatial.distance.cosine : Dense matrices only.
#     998 """
#     999 # 1.0 - cosine_similarity(X, Y) without copy
# -> 1000 S = cosine_similarity(X, Y)
#    1001 S *= -1
#    1002 S += 1
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1393, in cosine_similarity(X, Y, dense_output)
#    1358 """Compute cosine similarity between samples in X and Y.
#    1359
#    1360 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1389     Returns the cosine similarity between samples in X and Y.
#    1390 """
#    1391 # to avoid recursive import
# -> 1393 X, Y = check_pairwise_arrays(X, Y)
#    1395 X_normalized = normalize(X, copy=True)
#    1396 if X is Y:
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:163, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     154 else:
#     155     X = check_array(
#     156         X,
#     157         accept_sparse=accept_sparse,
#    (...)
#     161         estimator=estimator,
#     162     )
# --> 163     Y = check_array(
#     164         Y,
#     165         accept_sparse=accept_sparse,
#     166         dtype=dtype,
#     167         copy=copy,
#     168         force_all_finite=force_all_finite,
#     169         estimator=estimator,
#     170     )
#     172 if precomputed:
#     173     if X.shape[1] != Y.shape[0]:
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File c:\Users\k9942\anaconda3\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# MemoryError: Unable to allocate 185. MiB for an array with shape (169, 143458) and data type float64

# %%
distances.shape

# %%
indices.shape

# %%
movie_pivot.head()
# Out:
# User_ID   6.0        7.0        79.0       97.0       134.0      169.0      \
# Movie_ID
# 3                 0          0          0          0          0          0
# 8                 0          5          0          0          0          0
# 16                0          0          0          0          0          0
# 17                0          0          0          0          0          0
# 18                0          0          0          0          0          0
#
# User_ID   183.0      188.0      195.0      199.0      ...  2649308.0  \
# Movie_ID                                              ...
# 3                 0          0          0          0  ...          0
# 8                 0          0          0          0  ...          0
# 16                0          0          0          0  ...          0
# 17                0          0          0          0  ...          0
# 18                0          0          0          0  ...          4
#
# User_ID   2649328.0  2649331.0  2649335.0  2649336.0  2649370.0  2649378.0  \
# Movie_ID
# 3                 0          0          0          0          0          0
# 8                 0          0          0          4          0          0
# 16                0          0          0          0          0          0
# 17                0          0          0          0          0          0
# 18                0          0          0          0          0          0
#
# User_ID   2649388.0  2649426.0  2649429.0
# Movie_ID
# 3                 0          0          0
# 8                 0          0          0
# 16                0          0          0
# 17                0          4          0
# 18                0          0          0
#
# [5 rows x 143458 columns]

# %%
import numpy as np
# ISBN -> 행렬의 행의 위치(숫자) 
np.where(movie_pivot.index == 18)
# Out:
# (array([4], dtype=int64),)

# %%
movie_df[movie_df['Movie_ID'] == 18]
# Out:
#     Movie_ID  Year              Name
# 17        18  1994  Immortal Beloved

# %%
indices[18]

# %%
distances[18]

# %%
for i in range(n_neighbors):
    book_title = movie_df.loc[movie_df['Movie_ID'] == movie_pivot.index[indices[18][i]], 'Name'].values[0]
    distance = '{:.3f}'.format(distances[18][i])
    print(book_title, 'distance: ', distance)
