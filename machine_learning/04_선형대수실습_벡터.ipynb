# %% [markdown]
# ## 선형대수 실습 - 벡터

# %% [markdown]
# https://nbviewer.org/github/rickiepark/handson-ml2/blob/master/math_linear_algebra.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Vectors in Python

# %%
# video의 정보
[10.5, 5.2, 3.25, 7.0]

# This vector could represent a video that lasts 10.5 minutes, 
# but only 5.2% viewers watch for more than a minute, it gets 3.25 views per day on average, and it was flagged 7 times as spam.
# Out:
# [10.5, 5.2, 3.25, 7.0]

# %%
# video에 대한 머신러닝 예측 결과 (Output)
[0.8, 0.18, 0.02]
# [스팸일 확률, 클릭성낚시일 확률. 비디오가 노멀일 확률]
# Out:
# [0.8, 0.18, 0.02]

# %%
# 예측
# 키, 나이 -> 몸무게
# 벡터로 표현(1차원 배열) -> 스칼라(0차원 배열) 숫자 하나의 값으로 결과값이 나옴
[170, 30] #-> 65
[180, 35] #-> 75
[150, 15] #-> 60

# %% [markdown]
# 파이썬에서 벡터를 표현할 때는 리스트 형태 보다 넘파이의 배열의 형태가 원소들끼리 계산이 가능하기 때문에 더 빠르고 효율적이다.

# %%
video = np.array([10.5, 5.2, 3.25, 7.0])
video
# Out:
# array([10.5 ,  5.2 ,  3.25,  7.  ])

# %%
video.shape # 배열의 차원은 1차원 이지만, 벡터의 차원에서는 4차원이다.
# Out:
# (4,)

# %%
video.size # 원소의 개수
# Out:
# 4

# %% [markdown]
# - Plotting vectors

# %%
u = np.array([2, 5])
v = np.array([3, 1])

# %%
x_coords, y_coords = zip(u, v)

# %%
plt.scatter(x_coords, y_coords, color=["r","b"])
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()

# %%
def plot_vector2d(vector2d, origin=[0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)

# %%
plot_vector2d(u, color="r")
plot_vector2d(v, color="b")
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()

# %% [markdown]
# - 3D vectors

# %%
a = np.array([1, 2, 8])
b = np.array([5, 6, 3])

# %%
from mpl_toolkits.mplot3d import Axes3D

subplot3d = plt.subplot(111, projection='3d')
x_coords, y_coords, z_coords = zip(a,b)
subplot3d.scatter(x_coords, y_coords, z_coords)
subplot3d.set_zlim3d([0, 9])
plt.show()

# %%
def plot_vectors3d(ax, vectors3d, z0, **options):
    for v in vectors3d:
        x, y, z = v
        ax.plot([x,x], [y,y], [z0, z], color="gray", linestyle='dotted', marker=".")
    x_coords, y_coords, z_coords = zip(*vectors3d)
    ax.scatter(x_coords, y_coords, z_coords, **options)

subplot3d = plt.subplot(111, projection='3d')
subplot3d.set_zlim([0, 9])
plot_vectors3d(subplot3d, [a,b], 0, color=("r","b"))
plt.show()

# %% [markdown]
# - Norm: 길이

# %%
vector = [2, 5]

sum([element ** 2 for element in vector]) ** 0.5

# 0.5 제곱하면 루트이다
# Out:
# 5.385164807134504

# %%
def vector_norm(vector):
    squares = [element**2 for element in vector]
    return sum(squares)**0.5

print("||", u, "|| =")
vector_norm(u)
# Out:
# || [2 5] || =
# 5.385164807134504

# %%
import numpy.linalg as LA #(Linear Algebra: 선형대수학
LA.norm(u)
# Out:
# 5.385164807134504

# %%
radius = LA.norm(u)
plt.gca().add_artist(plt.Circle((0,0), radius, color="#DDDDDD"))
plot_vector2d(u, color="red")
plt.axis([0, 8.7, 0, 6])
plt.grid()
plt.show()

# %%
print(" ", u)
print("+", v)
print("-"*10)
u + v
# Out:
#   [2 5]
# + [3 1]
# ----------
# array([5, 6])

# %%
plot_vector2d(u, color="r")
plot_vector2d(v, color="b")
plot_vector2d(v, origin=u, color="b", linestyle="dotted")
plot_vector2d(u, origin=v, color="r", linestyle="dotted")
plot_vector2d(u+v, color="g")
plt.axis([0, 9, 0, 7])
plt.text(0.7, 3, "u", color="r", fontsize=18)
plt.text(4, 3, "u", color="r", fontsize=18)
plt.text(1.8, 0.2, "v", color="b", fontsize=18)
plt.text(3.1, 5.6, "v", color="b", fontsize=18)
plt.text(2.4, 2.5, "u+v", color="g", fontsize=18)
plt.grid()
plt.show()

# Vector addition is also associative, meaning that u+(v+w)=(u+v)+w

# %%
t1 = np.array([2, 0.25])
t2 = np.array([2.5, 3.5])
t3 = np.array([1, 2])

x_coords, y_coords = zip(t1, t2, t3, t1)
plt.plot(x_coords, y_coords, "c--", x_coords, y_coords, "co")

plot_vector2d(v, t1, color="r", linestyle=":")
plot_vector2d(v, t2, color="r", linestyle=":")
plot_vector2d(v, t3, color="r", linestyle=":")

t1b = t1 + v
t2b = t2 + v
t3b = t3 + v

x_coords_b, y_coords_b = zip(t1b, t2b, t3b, t1b)
plt.plot(x_coords_b, y_coords_b, "b-", x_coords_b, y_coords_b, "bo")

plt.text(4, 4.2, "v", color="r", fontsize=18)
plt.text(3, 2.3, "v", color="r", fontsize=18)
plt.text(3.5, 0.4, "v", color="r", fontsize=18)

plt.axis([0, 6, 0, 5])
plt.grid()
plt.show()

# %% [markdown]
# - Multiplication by a scalar

# %%
# 벡터의 스칼라를 곱하면 각 원소에 스칼라를 곱해주면 된다.
print("1.5 *", u, "=")

1.5 * u
# Out:
# 1.5 * [2 5] =
# array([3. , 7.5])

# %%
k = 2.5
t1c = k * t1
t2c = k * t2
t3c = k * t3

plt.plot(x_coords, y_coords, "c--", x_coords, y_coords, "co")

plot_vector2d(t1, color="r")
plot_vector2d(t2, color="r")
plot_vector2d(t3, color="r")

x_coords_c, y_coords_c = zip(t1c, t2c, t3c, t1c)
plt.plot(x_coords_c, y_coords_c, "b-", x_coords_c, y_coords_c, "bo")

plot_vector2d(k * t1, color="b", linestyle=":")
plot_vector2d(k * t2, color="b", linestyle=":")
plot_vector2d(k * t3, color="b", linestyle=":")

plt.axis([0, 9, 0, 9])
plt.grid()
plt.show()

# %%
# Scalar multiplication is commutative: λ×u=u×λ
# It is also associative: λ1×(λ2×u)=(λ1×λ2)×u
# Finally, it is distributive over addition of vectors: λ×(u+v)=λ×u+λ×v

# %% [markdown]
# - Zero, unit and normalized vectors
#
# * A zero-vector is a vector full of 0s.
# * A unit vector is a vector with a norm equal to 1.
# * The normalized vector of a non-null vector u noted u^, is the unit vector that points in the same direction as u.

# %% [markdown]
# - Dot product

# %%
# Dot product: 각 원소를 곱해서 더하는 것을 의미한다.
def dot_product(v1, v2):
    return sum(v1i * v2i for v1i, v2i in zip(v1, v2))

dot_product(u, v) # 아웃풋은 스칼라
# Out:
# 11

# %%
# elementwise multiplication은 dot product와 다름
print("  ",u)
print("* ",v, "(NOT a dot product)")
print("-"*10)

u * v
# Out:
#    [2 5]
# *  [3 1] (NOT a dot product)
# ----------
# array([6, 5])

# %% [markdown]
#  - Calculating the angle between vectors

# %%
# Cosine Similarity -> theta를 계산 (긱도)
def vector_angle(u, v):
    cos_theta = u.dot(v) / LA.norm(u) / LA.norm(v)
    return np.arccos(np.clip(cos_theta, -1, 1))

# %%
theta = vector_angle(np.array([1,0]), np.array([0,1])) 

print("Angle =", theta, "radians")
print("      =", theta * 180 / np.pi, "degrees")
# Out:
# Angle = 1.5707963267948966 radians
#       = 90.0 degrees
